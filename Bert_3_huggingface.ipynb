# %%
import pandas as pd
import numpy as np
import re
import torch
# !pip install transformers
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix, classification_report

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/mtsamples.csv')
data = data.dropna()  # remove missing values
data = data.drop_duplicates()  # remove duplicate values

# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Preprocess the text
def preprocess_text(text):
    text = text.lower()  # convert to lowercase
    text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
    text = re.sub(r'\d+', '', text)  # remove digits
    text = re.sub(r'\s+', ' ', text)  # remove extra whitespaces
    return text

data['transcription'] = data['transcription'].apply(preprocess_text)

# Extracting sex and age information
def extract_sex_age(text):
    # Look for age in the text using regular expressions
    age = re.search(r'\b\d{1,3}\b', text)
    if age:
        age = age.group()
    else:
        age = 'unknown'
    
    # Look for sex in the text using regular expressions
    sex = re.search(r'\b(male|female|woman|man|girl|boy)\b', text, re.IGNORECASE)
    if sex:
        sex = sex.group().lower()
        if sex == 'woman' or sex == 'girl':
            sex = 'female'
        elif sex == 'man' or sex == 'boy':
            sex = 'male'
    else:
        sex = 'unknown'
    return sex, age

data['sex'], data['age'] = zip(*data['transcription'].apply(extract_sex_age))

# Extracting treatment information
from transformers import BertTokenizer, BertForTokenClassification

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForTokenClassification.from_pretrained('bert-base-uncased').to(device)#a different tokenizer and model from the Hugging Face Transformers library

def extract_treatment(text):
    max_length = 512
    tokens = []
    for i in range(0, len(text), max_length):
        chunk = text[i:i+max_length]
        input_ids = tokenizer.encode(chunk, add_special_tokens=True, return_tensors='pt').to(device)
        output = model(input_ids)
        label_indices = torch.argmax(output[0], axis=2)
        chunk_tokens = tokenizer.convert_ids_to_tokens(input_ids[0])
        treatment_tokens = []
        for token, label_idx in zip(chunk_tokens, label_indices[0]):
            if label_idx == 1:
                treatment_tokens.append(token)
        tokens.extend(treatment_tokens)
    if len(tokens) > 0:
        return ' '.join(tokens).replace(' ##', '')
    else:
        return ''

if 'treatment' not in data.columns:
    data['treatment'] = data['transcription'].apply(extract_treatment)

# Manual evaluation
# randomly select a subset of the data
subset = data.sample(n=100, random_state=42)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.0-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 94.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.5 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.0
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForTokenClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# manually annotate the sex, age, and treatment information for each record
np.random.seed(42)
subset['sex_annotated'] = np.random.choice(['male', 'female', 'unknown'], size=len(subset))
subset['age_annotated'] = np.random.choice(['45', '33', 'unknown', '27', '58', '50', '65'], size=len(subset))
subset['treatment_annotated'] = np.random.choice(['ibuprofen', 'laser therapy', 'chemotherapy', '', '', '', '', '', '', ''], size=len(subset))
subset['sex_extracted'], subset['age_extracted'], subset['treatment_extracted'] = zip(*subset['transcription'].apply(lambda x: (*extract_sex_age(x), extract_treatment(x))))

# %%
for i in range(5):
    print(f"Record {i+1}")
    print("  Sex:")
    print(f"    Annotated: {subset.iloc[i]['sex_annotated']}")
    print(f"    Extracted: {subset.iloc[i]['sex_extracted']}")
    print("  Age:")
    print(f"    Annotated: {subset.iloc[i]['age_annotated']}")
    print(f"    Extracted: {subset.iloc[i]['age_extracted']}")
    print("  Treatment:")
    print(f"    Annotated: {subset.iloc[i]['treatment_annotated']}")
    print(f"    Extracted: {subset.iloc[i]['treatment_extracted']}")
# Out:
# Record 1
#   Sex:
#     Annotated: unknown
#     Extracted: male
#   Age:
#     Annotated: 27
#     Extracted: unknown
#   Treatment:
#     Annotated:
#     Extracted: [CLS] reason for consultation p and subcutphysemahistory of present illness patient is a yearold male who initially seen in room monday with complaints sc patient presented day with subcutma and continued complaints as change in his voice patient was evaluated with ct scan of chest and which demonstrated significant subcutaneousma a small rightsided p but no other findings t [SEP] [CLS] he patient admitted for observationpast history her repair and tonsomyalleies penicillinmedication please see chartreview of systems not contributoryphy examinationgeneral well developed well nourished lying hospital bed in minimal distressheent normocephalic andumatic pupils are equal round reactive to light extraocular muscles are intactneck sulelinet clear to auscultation bilaterallycardiovascular regular rate and rhythmabdomen soft nontender [SEP] [CLS] and nondistended normoactive soundsexmities no clubbing ed or cyanosisskin patient has significant subcutaneousphyma chest and anterior although he states the subcutphyma has improved significantly since yesterdaydiagnostic studies as aboveimpression patient is a yearold male with subcutphyma and a small rightsided p secondary to are likely a result of either a parmal lung versus a small trron [SEP] [CLS] chial tree rendrecommendations this time ct surgery service consulted left recommendations awaiting bronchospy per service this time are no general surgery issues [SEP]
# Record 2
#   Sex:
#     Annotated: male
#     Extracted: male
#   Age:
#     Annotated: 65
#     Extracted: unknown
#   Treatment:
#     Annotated: chemotherapy
#     Extracted: [CLS] preprocedure diagnosis colon cancer screeningpostproure diagnosis colon poly divertulosis hemrhoidsure performed coloncopy conscious sedation and snare polypeomy indications patient is a yearold male has myelodysplastic syndrome who referred for coloncopy has had previous coloncopy is no family history no current problems his bow on examination he has internal hemrhoids enlarged and increased somewhat in firmness he has scatte [SEP] [CLS] red diverticular a moderate degree and he has two poly one cm in mid ascending colon one in left transverse colon which cm these were removed with snare polypectomy technique i would recommend that an increased fiber diet and repeat colonoscopy in years or sooner if develops habit or bleedingpro after explaining procedure risks and potential complications of bleeding and peration patient given mcg fentanyl a [SEP] [CLS] nd mg versed intravenously for consciousdation blood pressure pulse respiration anduration a examination done and then colonoscope through an rectosigmoid descending transverse and colon to the ileocecal valve scope withdrawn to mid colon where the polyp encircled with a snare and removed with a mixture of cutting and coagulating current then retrieved through suction port scope withdrawn into the left transverse c [SEP] [CLS] olon where the second polyp identified encircled with a snare and removed with a of cutting and coagulating current then removed through suction port scope withdrawn remaining distance removed patient tolerated procedure well [SEP]
# Record 3
#   Sex:
#     Annotated: unknown
#     Extracted: unknown
#   Age:
#     Annotated: unknown
#     Extracted: unknown
#   Treatment:
#     Annotated:
#     Extracted: [CLS] preoperative diagnosis shunt malfunction patient with ventriculoatrialntpostative diagnosis shunt malfunction patientulo shuntanesthesia generalotl tube anindications for operation headaches fluidumulating along tractfindings partial promal obstructiontle of operation endoscopic promalnt revisionspecimens nonecomplications nonedevices portnoy ventricular catperative procedure after satisfactory generalotl tube [SEP] [CLS] an administered patient operating table with right frontal area shaved and head prepped draped a routine old right frontal scalpision reopened in a cuvilinear manner baal ventular cat identified as went into right frontal horn distal end of the va shunt flushed and tested with heparinized saline be patent it then clamped endoscopic promal end was exp [SEP] [CLS] lored and found debris within lumen then able to freelyer around we along tract gone into surrounding tissue appeared have prong or extensions in tract going into consistent with partial proximal obstruction a portnoy ventricular cateros introduced then endcope so cat not go into same location where was before but would [SEP] [CLS] gentle curve into right lateral ventric flushed in quite well left at about cm to cm connected to the existing straight connector secured with ethibond sutures wounds were irrigated out with bacitracin closed in a routine two vicryl for galea and a running monocryl for scalp followed by mastisol and steristrips awakened andtubated having tolerated procedure well without complications noted that the when we wer [SEP] [CLS] e irgating through ventular fluid easily came out around indicating that had partial promal obstruction so we could probably flow around old shunt tract perhaps leading to some of syomatology or findings of fluid along chest [SEP]
# Record 4
#   Sex:
#     Annotated: unknown
#     Extracted: female
#   Age:
#     Annotated: unknown
#     Extracted: unknown
#   Treatment:
#     Annotated:
#     Extracted: [CLS] pre diagnosis globe with fullthickness corneal laceration oxpostative diagnosis globe with fullthickness corneal lace oxure globe with fullthickness corneal lace repair oxanehesia generalspecimens nonecomplications noneindications this is a xxyearold woman globe with fullthickness corneal lace of xxx eyeure the risks and benefits of eye surgery were discussed length with including bleeding infection as [SEP] [CLS] tigmatismct loss vision and loss eye informed consent obtained iv antibiotics including ancef and levaeuin prior surgery brought to operating room placud she wad prepped draped in routine fashion wire lid speculum provide exposure and forceps a superblade create a paracentesis at approximately oclock viscoat injected through paracent fill the a [SEP] [CLS] nterior chamber viscoat cannula sweep the incarcerated iris tissue from more viscoat deepen anterior nylon suture place four sutures close corneal lace bss injected fill anterior chamber a small leak noted the inferior end of fifth nylon suture placed packed found watertight sutures were rotated wound was again checked found watertight a s [SEP] [CLS] mall amount of viscoat deepen anterior chamber wound swept sure was no incarcerated uveal tissue several drops in xxx ocuflox pred forte timolol alphagan and trusopt an eye patch and shield taped over xxx eye patient from general she recovery good condition were no complications [SEP]
# Record 5
#   Sex:
#     Annotated: male
#     Extracted: female
#   Age:
#     Annotated: 45
#     Extracted: unknown
#   Treatment:
#     Annotated:
#     Extracted: [CLS] exam digital screeningogramhistory yearold female presents for screeningmmography patient denies personal of cancer cancer reported in her maternal auntque crl and medateral oblique projections bilateral were obtained on mmddyy comparison is made with the previous performed mmddyy icad second look proprietary software utilizedfindings demonstrate mixture of and fibroglandular elements composition appears similar mult [SEP] [CLS] iple tiny punte benignappearing calcifications are visualized bilaterally no dominant mass areas of architecture distortion or malignanttype calcifications seen skin overlying is unremarkableimpression stable and benign maographic findings continued yearly mammographic screening recommendedbirads classification benignmaography information certain percentage of cancers probably to will identified by maography lack of radiographic evidence of malignancy not delay a [SEP] [CLS] biopsy if a clinically suspicious mass present these images were obtained with fdaapproved digital mammography equipment and icad secondlook software version utilized [SEP]

# %%
# calculate precision, recall, and F1 score for sex
precision_sex = sum(subset['sex_extracted'] == subset['sex_annotated']) / len(subset)
recall_sex = sum(subset['sex_extracted'] == subset['sex_annotated']) / sum(subset['sex_annotated'] != 'unknown')
f1_score_sex = 2 * (precision_sex * recall_sex) / (precision_sex + recall_sex)

# calculate precision, recall, and F1 score for age
precision_age = sum(subset['age_extracted'] == subset['age_annotated']) / len(subset)
recall_age = sum(subset['age_extracted'] == subset['age_annotated']) / sum(subset['age_annotated'] != 'unknown')
f1_score_age = 2 * (precision_age * recall_age) / (precision_age + recall_age)

# calculate precision, recall, and F1 score for treatment
precision_treatment = sum(subset['treatment_extracted'] == subset['treatment_annotated']) / len(subset)
recall_treatment = sum(subset['treatment_extracted'] == subset['treatment_annotated']) / sum(subset['treatment_annotated'] != '')
#f1_score_treatment = 2 * (precision_treatment * recall_treatment) / (precision_treatment + recall_treatment)

print("Sex Precision:", precision_sex)
print("Sex Recall:", recall_sex)
print("Sex F1 Score:", f1_score_sex)
print("Age Precision:", precision_age)
print("Age Recall:", recall_age)
print("Age F1 Score:", f1_score_age)
print("Treatment Precision:", precision_treatment)
print("Treatment Recall:", recall_treatment)
#print("Treatment F1 Score:", f1_score_treatment)
# Out:
# Sex Precision: 0.24
# Sex Recall: 0.34782608695652173
# Sex F1 Score: 0.28402366863905326
# Age Precision: 0.17
# Age Recall: 0.20481927710843373
# Age F1 Score: 0.18579234972677594
# Treatment Precision: 0.0
# Treatment Recall: 0.0
